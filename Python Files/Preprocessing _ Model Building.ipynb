# %%
# %%capture

# !pip install snowflake-connector-python

# %%
# %%capture

# !pip install snowflake-sqlalchemy

# %%
# %%capture

# !pip install xgboost

# %%
import os
import pickle
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn import metrics

import sqlalchemy
import snowflake.connector
from sqlalchemy import create_engine
from snowflake.sqlalchemy import *

import xgboost
from datetime import datetime, timedelta
import time  
import pytz    
tz_NY = pytz.timezone('Europe/London')

import snowflake_creds

import warnings
warnings.filterwarnings('ignore')
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/snowflake/sqlalchemy/base.py:1068: SAWarning: The GenericFunction 'flatten' is already registered and is going to be overridden.
#   functions.register_function("flatten", flatten)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/xgboost/core.py:265: FutureWarning: Your system has an old version of glibc (< 2.28). We will stop supporting Linux distros with glibc older than 2.28 after **May 31, 2025**. Please upgrade to a recent Linux distro (with glibc 2.28+) to use future versions of XGBoost.
# Note: You have installed the 'manylinux2014' variant of XGBoost. Certain features such as GPU algorithms or federated learning are not available. To use these features, please upgrade to a recent Linux distro with glibc 2.28+, and install the 'manylinux_2_28' variant.
#   warnings.warn(

# %%
# Creating a Snowflake connection engine
engine = create_engine(URL(
        account="vvkvijp-xf90326",
        user= snowflake_creds.USER_NAME,
        password= snowflake_creds.PASSWORD,
        role="ACCOUNTADMIN",
        warehouse="COMPUTE_WH",
        database="HEALTHDB",
        schema="HEALTHSCHEMA"
    ))

# %%
query = """
WITH BASE AS (
    SELECT 
        CASE_ID,
        COALESCE(HOSPITAL_CODE, 0) AS HOSPITAL_CODE,
        COALESCE(HOSPITAL_TYPE_CODE, 'None') AS HOSPITAL_TYPE_CODE,
        COALESCE(CITY_CODE_HOSPITAL, 0) AS CITY_CODE_HOSPITAL,
        COALESCE(HOSPITAL_REGION_CODE, 'None') AS HOSPITAL_REGION_CODE,
        COALESCE(AVAILABLE_EXTRA_ROOMS_IN_HOSPITAL, 0) AS AVAILABLE_EXTRA_ROOMS_IN_HOSPITAL,
        COALESCE(DEPARTMENT, 'None') AS DEPARTMENT,
        COALESCE(WARD_TYPE, 'None') AS WARD_TYPE,
        COALESCE(WARD_FACILITY_CODE, 'None') AS WARD_FACILITY_CODE,
        COALESCE(BED_GRADE, 0) AS BED_GRADE,
        PATIENTID,
        COALESCE(CITY_CODE_PATIENT, 0) AS CITY_CODE_PATIENT,
        COALESCE(TYPE_OF_ADMISSION, 'None') AS TYPE_OF_ADMISSION,
        COALESCE(SEVERITY_OF_ILLNESS, 'Minor') AS SEVERITY_OF_ILLNESS,
        COALESCE(VISITORS_WITH_PATIENT, 0) AS VISITORS_WITH_PATIENT,
        COALESCE(AGE, 'None') AS AGE,
        COALESCE(ADMISSION_DEPOSIT, 0) AS ADMISSION_DEPOSIT,
        ADMISSION_DATE,
        DISCHARGE_DATE
    FROM HEALTHDB.HEALTHSCHEMA.HEALTH_DATA
),

BASE_WITH_FEATURES AS (
    SELECT 
        *,
        MONTHNAME(ADMISSION_DATE) AS ADMISSION_MONTH,
        DAYNAME(ADMISSION_DATE) AS ADMISSION_DAY,
        CONCAT(TYPE_OF_ADMISSION, '-', SEVERITY_OF_ILLNESS) AS ADMISSION_ILLNESS,
        CONCAT(SEVERITY_OF_ILLNESS, '-', BED_GRADE) AS ILLNESS_BEDGRADE,
        CONCAT(DEPARTMENT, '-', SEVERITY_OF_ILLNESS) AS DEPARTMENT_ILLNESS,
        DATEDIFF(day, ADMISSION_DATE, DISCHARGE_DATE) AS LOS
    FROM BASE
)    

SELECT * 
FROM BASE_WITH_FEATURES
"""

# %%
with engine.connect() as conn:
    data = pd.DataFrame(pd.read_sql(query,conn))
    data.columns = [col.upper() for col in data.columns.tolist()]

# %%
print(data.shape)
data.head()
# Out:
# (236704, 25)
#    CASE_ID  HOSPITAL_CODE HOSPITAL_TYPE_CODE  CITY_CODE_HOSPITAL  \
# 0        1              8                  c                   3
# 1        3             10                  e                   1
# 2        4             26                  b                   2
# 3        5             26                  b                   2
# 4        6             23                  a                   6
#
#   HOSPITAL_REGION_CODE  AVAILABLE_EXTRA_ROOMS_IN_HOSPITAL    DEPARTMENT  \
# 0                    Z                                  3  radiotherapy
# 1                    X                                  2    anesthesia
# 2                    Y                                  2  radiotherapy
# 3                    Y                                  2  radiotherapy
# 4                    X                                  2    anesthesia
#
#   WARD_TYPE WARD_FACILITY_CODE  BED_GRADE  PATIENTID  CITY_CODE_PATIENT  \
# 0         R                  F          2      31397                  7
# 1         S                  E          2      31397                  7
# 2         R                  D          2      31397                  7
# 3         S                  D          2      31397                  7
# 4         S                  F          2      31397                  7
#
#   TYPE_OF_ADMISSION SEVERITY_OF_ILLNESS  VISITORS_WITH_PATIENT    AGE  \
# 0         Emergency             Extreme                      2  51-60
# 1            Trauma             Extreme                      2  51-60
# 2            Trauma             Extreme                      2  51-60
# 3            Trauma             Extreme                      2  51-60
# 4            Trauma             Extreme                      2  51-60
#
#    ADMISSION_DEPOSIT ADMISSION_DATE DISCHARGE_DATE ADMISSION_MONTH  \
# 0               4911     2022-08-10     2022-08-20             Aug
# 1               4745     2022-09-09     2022-10-19             Sep
# 2               7272     2022-09-22     2022-11-11             Sep
# 3               5558     2022-11-02     2022-12-22             Nov
# 4               4449     2022-09-16     2022-10-06             Sep
#
#   ADMISSION_DAY  ADMISSION_ILLNESS ILLNESS_BEDGRADE    DEPARTMENT_ILLNESS  LOS
# 0           Wed  Emergency-Extreme        Extreme-2  radiotherapy-Extreme   10
# 1           Fri     Trauma-Extreme        Extreme-2    anesthesia-Extreme   40
# 2           Thu     Trauma-Extreme        Extreme-2  radiotherapy-Extreme   50
# 3           Wed     Trauma-Extreme        Extreme-2  radiotherapy-Extreme   50
# 4           Fri     Trauma-Extreme        Extreme-2    anesthesia-Extreme   20

# %% [markdown]
# ## Preprocessing:

# %% [markdown]
# * Dropping unwanted columns
# * One-Hot encoding categorical columns
# * Setting the CASE_ID as index

# %%
cols_to_drop = ['HOSPITAL_CODE','PATIENTID','ADMISSION_DATE','DISCHARGE_DATE']

# %%
data_pre = data.copy()

# %%
# Dropping columns

print("Before dropping: ", data_pre.shape)
data_pre = data_pre.drop(cols_to_drop,axis=1)
print("After dropping: ", data_pre.shape)
# Out:
# Before dropping:  (236704, 25)
# After dropping:  (236704, 21)

# %%
data_pre.set_index('CASE_ID',inplace=True)

# %%
data_pre.head(3)
# Out:
#         HOSPITAL_TYPE_CODE  CITY_CODE_HOSPITAL HOSPITAL_REGION_CODE  \
# CASE_ID
# 1                        c                   3                    Z
# 3                        e                   1                    X
# 4                        b                   2                    Y
#
#          AVAILABLE_EXTRA_ROOMS_IN_HOSPITAL    DEPARTMENT WARD_TYPE  \
# CASE_ID
# 1                                        3  radiotherapy         R
# 3                                        2    anesthesia         S
# 4                                        2  radiotherapy         R
#
#         WARD_FACILITY_CODE  BED_GRADE  CITY_CODE_PATIENT TYPE_OF_ADMISSION  \
# CASE_ID
# 1                        F          2                  7         Emergency
# 3                        E          2                  7            Trauma
# 4                        D          2                  7            Trauma
#
#         SEVERITY_OF_ILLNESS  VISITORS_WITH_PATIENT    AGE  ADMISSION_DEPOSIT  \
# CASE_ID
# 1                   Extreme                      2  51-60               4911
# 3                   Extreme                      2  51-60               4745
# 4                   Extreme                      2  51-60               7272
#
#         ADMISSION_MONTH ADMISSION_DAY  ADMISSION_ILLNESS ILLNESS_BEDGRADE  \
# CASE_ID
# 1                   Aug           Wed  Emergency-Extreme        Extreme-2
# 3                   Sep           Fri     Trauma-Extreme        Extreme-2
# 4                   Sep           Thu     Trauma-Extreme        Extreme-2
#
#            DEPARTMENT_ILLNESS  LOS
# CASE_ID
# 1        radiotherapy-Extreme   10
# 3          anesthesia-Extreme   40
# 4        radiotherapy-Extreme   50

# %%
# Fixing the data types issue
num_columns = ['AVAILABLE_EXTRA_ROOMS_IN_HOSPITAL','VISITORS_WITH_PATIENT','ADMISSION_DEPOSIT','LOS']
cat_columns = [col for col in data_pre.columns.tolist() if col not in num_columns]

# %%
data_pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 236704 entries, 1 to 255883
# Data columns (total 20 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   HOSPITAL_TYPE_CODE                 236704 non-null  object
#  1   CITY_CODE_HOSPITAL                 236704 non-null  int64
#  2   HOSPITAL_REGION_CODE               236704 non-null  object
#  3   AVAILABLE_EXTRA_ROOMS_IN_HOSPITAL  236704 non-null  int64
#  4   DEPARTMENT                         236704 non-null  object
#  5   WARD_TYPE                          236704 non-null  object
#  6   WARD_FACILITY_CODE                 236704 non-null  object
#  7   BED_GRADE                          236704 non-null  int64
#  8   CITY_CODE_PATIENT                  236704 non-null  int64
#  9   TYPE_OF_ADMISSION                  236704 non-null  object
#  10  SEVERITY_OF_ILLNESS                236704 non-null  object
#  11  VISITORS_WITH_PATIENT              236704 non-null  int64
#  12  AGE                                236704 non-null  object
#  13  ADMISSION_DEPOSIT                  236704 non-null  int64
#  14  ADMISSION_MONTH                    236704 non-null  object
#  15  ADMISSION_DAY                      236704 non-null  object
#  16  ADMISSION_ILLNESS                  236704 non-null  object
#  17  ILLNESS_BEDGRADE                   236704 non-null  object
#  18  DEPARTMENT_ILLNESS                 236704 non-null  object
#  19  LOS                                236704 non-null  int64
# dtypes: int64(7), object(13)
# memory usage: 37.9+ MB

# %%
for col in cat_columns:
    data_pre[col] = data_pre[col].astype(object)
    
for col in num_columns:
    data_pre[col] = data_pre[col].astype(int)

# %%
data_pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 236704 entries, 1 to 255883
# Data columns (total 20 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   HOSPITAL_TYPE_CODE                 236704 non-null  object
#  1   CITY_CODE_HOSPITAL                 236704 non-null  object
#  2   HOSPITAL_REGION_CODE               236704 non-null  object
#  3   AVAILABLE_EXTRA_ROOMS_IN_HOSPITAL  236704 non-null  int64
#  4   DEPARTMENT                         236704 non-null  object
#  5   WARD_TYPE                          236704 non-null  object
#  6   WARD_FACILITY_CODE                 236704 non-null  object
#  7   BED_GRADE                          236704 non-null  object
#  8   CITY_CODE_PATIENT                  236704 non-null  object
#  9   TYPE_OF_ADMISSION                  236704 non-null  object
#  10  SEVERITY_OF_ILLNESS                236704 non-null  object
#  11  VISITORS_WITH_PATIENT              236704 non-null  int64
#  12  AGE                                236704 non-null  object
#  13  ADMISSION_DEPOSIT                  236704 non-null  int64
#  14  ADMISSION_MONTH                    236704 non-null  object
#  15  ADMISSION_DAY                      236704 non-null  object
#  16  ADMISSION_ILLNESS                  236704 non-null  object
#  17  ILLNESS_BEDGRADE                   236704 non-null  object
#  18  DEPARTMENT_ILLNESS                 236704 non-null  object
#  19  LOS                                236704 non-null  int64
# dtypes: int64(4), object(16)
# memory usage: 37.9+ MB

# %%
print("After dropping: ", data_pre.shape)
# Out:
# After dropping:  (236704, 20)

# %%
# One-Hot Encoding
data_after_process = pd.get_dummies(data_pre, drop_first=True)

# %%
print(data_after_process.shape)
data_after_process.head()
# Out:
# (236704, 134)
#          AVAILABLE_EXTRA_ROOMS_IN_HOSPITAL  VISITORS_WITH_PATIENT  \
# CASE_ID
# 1                                        3                      2
# 3                                        2                      2
# 4                                        2                      2
# 5                                        2                      2
# 6                                        2                      2
#
#          ADMISSION_DEPOSIT  LOS  HOSPITAL_TYPE_CODE_b  HOSPITAL_TYPE_CODE_c  \
# CASE_ID
# 1                     4911   10                 False                  True
# 3                     4745   40                 False                 False
# 4                     7272   50                  True                 False
# 5                     5558   50                  True                 False
# 6                     4449   20                 False                 False
#
#          HOSPITAL_TYPE_CODE_d  HOSPITAL_TYPE_CODE_e  HOSPITAL_TYPE_CODE_f  \
# CASE_ID
# 1                       False                 False                 False
# 3                       False                  True                 False
# 4                       False                 False                 False
# 5                       False                 False                 False
# 6                       False                 False                 False
#
#          HOSPITAL_TYPE_CODE_g  CITY_CODE_HOSPITAL_2  CITY_CODE_HOSPITAL_3  \
# CASE_ID
# 1                       False                 False                  True
# 3                       False                 False                 False
# 4                       False                  True                 False
# 5                       False                  True                 False
# 6                       False                 False                 False
#
#          CITY_CODE_HOSPITAL_4  CITY_CODE_HOSPITAL_5  CITY_CODE_HOSPITAL_6  \
# CASE_ID
# 1                       False                 False                 False
# 3                       False                 False                 False
# 4                       False                 False                 False
# 5                       False                 False                 False
# 6                       False                 False                  True
#
#          CITY_CODE_HOSPITAL_7  CITY_CODE_HOSPITAL_9  CITY_CODE_HOSPITAL_10  \
# CASE_ID
# 1                       False                 False                  False
# 3                       False                 False                  False
# 4                       False                 False                  False
# 5                       False                 False                  False
# 6                       False                 False                  False
#
#          CITY_CODE_HOSPITAL_11  CITY_CODE_HOSPITAL_13  HOSPITAL_REGION_CODE_Y  \
# CASE_ID
# 1                        False                  False                   False
# 3                        False                  False                   False
# 4                        False                  False                    True
# 5                        False                  False                    True
# 6                        False                  False                   False
#
#          HOSPITAL_REGION_CODE_Z  DEPARTMENT_anesthesia  DEPARTMENT_gynecology  \
# CASE_ID
# 1                          True                  False                  False
# 3                         False                   True                  False
# 4                         False                  False                  False
# 5                         False                  False                  False
# 6                         False                   True                  False
#
#          DEPARTMENT_radiotherapy  DEPARTMENT_surgery  WARD_TYPE_Q  \
# CASE_ID
# 1                           True               False        False
# 3                          False               False        False
# 4                           True               False        False
# 5                           True               False        False
# 6                          False               False        False
#
#          WARD_TYPE_R  WARD_TYPE_S  WARD_TYPE_T  WARD_TYPE_U  \
# CASE_ID
# 1               True        False        False        False
# 3              False         True        False        False
# 4               True        False        False        False
# 5              False         True        False        False
# 6              False         True        False        False
#
#          WARD_FACILITY_CODE_B  WARD_FACILITY_CODE_C  WARD_FACILITY_CODE_D  \
# CASE_ID
# 1                       False                 False                 False
# 3                       False                 False                 False
# 4                       False                 False                  True
# 5                       False                 False                  True
# 6                       False                 False                 False
#
#          WARD_FACILITY_CODE_E  WARD_FACILITY_CODE_F  BED_GRADE_1  BED_GRADE_2  \
# CASE_ID
# 1                       False                  True        False         True
# 3                        True                 False        False         True
# 4                       False                 False        False         True
# 5                       False                 False        False         True
# 6                       False                  True        False         True
#
#          BED_GRADE_3  BED_GRADE_4  CITY_CODE_PATIENT_1  CITY_CODE_PATIENT_2  \
# CASE_ID
# 1              False        False                False                False
# 3              False        False                False                False
# 4              False        False                False                False
# 5              False        False                False                False
# 6              False        False                False                False
#
#          CITY_CODE_PATIENT_3  CITY_CODE_PATIENT_4  CITY_CODE_PATIENT_5  \
# CASE_ID
# 1                      False                False                False
# 3                      False                False                False
# 4                      False                False                False
# 5                      False                False                False
# 6                      False                False                False
#
#          CITY_CODE_PATIENT_6  CITY_CODE_PATIENT_7  CITY_CODE_PATIENT_8  \
# CASE_ID
# 1                      False                 True                False
# 3                      False                 True                False
# 4                      False                 True                False
# 5                      False                 True                False
# 6                      False                 True                False
#
#          CITY_CODE_PATIENT_9  CITY_CODE_PATIENT_10  CITY_CODE_PATIENT_11  \
# CASE_ID
# 1                      False                 False                 False
# 3                      False                 False                 False
# 4                      False                 False                 False
# 5                      False                 False                 False
# 6                      False                 False                 False
#
#          CITY_CODE_PATIENT_12  CITY_CODE_PATIENT_13  CITY_CODE_PATIENT_14  \
# CASE_ID
# 1                       False                 False                 False
# 3                       False                 False                 False
# 4                       False                 False                 False
# 5                       False                 False                 False
# 6                       False                 False                 False
#
#          CITY_CODE_PATIENT_15  CITY_CODE_PATIENT_16  CITY_CODE_PATIENT_18  \
# CASE_ID
# 1                       False                 False                 False
# 3                       False                 False                 False
# 4                       False                 False                 False
# 5                       False                 False                 False
# 6                       False                 False                 False
#
#          CITY_CODE_PATIENT_19  CITY_CODE_PATIENT_20  CITY_CODE_PATIENT_21  \
# CASE_ID
# 1                       False                 False                 False
# 3                       False                 False                 False
# 4                       False                 False                 False
# 5                       False                 False                 False
# 6                       False                 False                 False
#
#          CITY_CODE_PATIENT_22  CITY_CODE_PATIENT_23  CITY_CODE_PATIENT_24  \
# CASE_ID
# 1                       False                 False                 False
# 3                       False                 False                 False
# 4                       False                 False                 False
# 5                       False                 False                 False
# 6                       False                 False                 False
#
#          CITY_CODE_PATIENT_25  CITY_CODE_PATIENT_26  CITY_CODE_PATIENT_27  \
# CASE_ID
# 1                       False                 False                 False
# 3                       False                 False                 False
# 4                       False                 False                 False
# 5                       False                 False                 False
# 6                       False                 False                 False
#
#          CITY_CODE_PATIENT_28  CITY_CODE_PATIENT_29  CITY_CODE_PATIENT_30  \
# CASE_ID
# 1                       False                 False                 False
# 3                       False                 False                 False
# 4                       False                 False                 False
# 5                       False                 False                 False
# 6                       False                 False                 False
#
#          CITY_CODE_PATIENT_31  CITY_CODE_PATIENT_32  CITY_CODE_PATIENT_33  \
# CASE_ID
# 1                       False                 False                 False
# 3                       False                 False                 False
# 4                       False                 False                 False
# 5                       False                 False                 False
# 6                       False                 False                 False
#
#          CITY_CODE_PATIENT_34  CITY_CODE_PATIENT_35  CITY_CODE_PATIENT_36  \
# CASE_ID
# 1                       False                 False                 False
# 3                       False                 False                 False
# 4                       False                 False                 False
# 5                       False                 False                 False
# 6                       False                 False                 False
#
#          CITY_CODE_PATIENT_37  TYPE_OF_ADMISSION_Trauma  \
# CASE_ID
# 1                       False                     False
# 3                       False                      True
# 4                       False                      True
# 5                       False                      True
# 6                       False                      True
#
#          TYPE_OF_ADMISSION_Urgent  SEVERITY_OF_ILLNESS_Minor  \
# CASE_ID
# 1                           False                      False
# 3                           False                      False
# 4                           False                      False
# 5                           False                      False
# 6                           False                      False
#
#          SEVERITY_OF_ILLNESS_Moderate  AGE_20-Nov  AGE_21-30  AGE_31-40  \
# CASE_ID
# 1                               False       False      False      False
# 3                               False       False      False      False
# 4                               False       False      False      False
# 5                               False       False      False      False
# 6                               False       False      False      False
#
#          AGE_41-50  AGE_51-60  AGE_61-70  AGE_71-80  AGE_81-90  AGE_91-100  \
# CASE_ID
# 1            False       True      False      False      False       False
# 3            False       True      False      False      False       False
# 4            False       True      False      False      False       False
# 5            False       True      False      False      False       False
# 6            False       True      False      False      False       False
#
#          ADMISSION_MONTH_Nov  ADMISSION_MONTH_Oct  ADMISSION_MONTH_Sep  \
# CASE_ID
# 1                      False                False                False
# 3                      False                False                 True
# 4                      False                False                 True
# 5                       True                False                False
# 6                      False                False                 True
#
#          ADMISSION_DAY_Mon  ADMISSION_DAY_Sat  ADMISSION_DAY_Sun  \
# CASE_ID
# 1                    False              False              False
# 3                    False              False              False
# 4                    False              False              False
# 5                    False              False              False
# 6                    False              False              False
#
#          ADMISSION_DAY_Thu  ADMISSION_DAY_Tue  ADMISSION_DAY_Wed  \
# CASE_ID
# 1                    False              False               True
# 3                    False              False              False
# 4                     True              False              False
# 5                    False              False               True
# 6                    False              False              False
#
#          ADMISSION_ILLNESS_Emergency-Minor  \
# CASE_ID
# 1                                    False
# 3                                    False
# 4                                    False
# 5                                    False
# 6                                    False
#
#          ADMISSION_ILLNESS_Emergency-Moderate  \
# CASE_ID
# 1                                       False
# 3                                       False
# 4                                       False
# 5                                       False
# 6                                       False
#
#          ADMISSION_ILLNESS_Trauma-Extreme  ADMISSION_ILLNESS_Trauma-Minor  \
# CASE_ID
# 1                                   False                           False
# 3                                    True                           False
# 4                                    True                           False
# 5                                    True                           False
# 6                                    True                           False
#
#          ADMISSION_ILLNESS_Trauma-Moderate  ADMISSION_ILLNESS_Urgent-Extreme  \
# CASE_ID
# 1                                    False                             False
# 3                                    False                             False
# 4                                    False                             False
# 5                                    False                             False
# 6                                    False                             False
#
#          ADMISSION_ILLNESS_Urgent-Minor  ADMISSION_ILLNESS_Urgent-Moderate  \
# CASE_ID
# 1                                 False                              False
# 3                                 False                              False
# 4                                 False                              False
# 5                                 False                              False
# 6                                 False                              False
#
#          ILLNESS_BEDGRADE_Extreme-1  ILLNESS_BEDGRADE_Extreme-2  \
# CASE_ID
# 1                             False                        True
# 3                             False                        True
# 4                             False                        True
# 5                             False                        True
# 6                             False                        True
#
#          ILLNESS_BEDGRADE_Extreme-3  ILLNESS_BEDGRADE_Extreme-4  \
# CASE_ID
# 1                             False                       False
# 3                             False                       False
# 4                             False                       False
# 5                             False                       False
# 6                             False                       False
#
#          ILLNESS_BEDGRADE_Minor-0  ILLNESS_BEDGRADE_Minor-1  \
# CASE_ID
# 1                           False                     False
# 3                           False                     False
# 4                           False                     False
# 5                           False                     False
# 6                           False                     False
#
#          ILLNESS_BEDGRADE_Minor-2  ILLNESS_BEDGRADE_Minor-3  \
# CASE_ID
# 1                           False                     False
# 3                           False                     False
# 4                           False                     False
# 5                           False                     False
# 6                           False                     False
#
#          ILLNESS_BEDGRADE_Minor-4  ILLNESS_BEDGRADE_Moderate-0  \
# CASE_ID
# 1                           False                        False
# 3                           False                        False
# 4                           False                        False
# 5                           False                        False
# 6                           False                        False
#
#          ILLNESS_BEDGRADE_Moderate-1  ILLNESS_BEDGRADE_Moderate-2  \
# CASE_ID
# 1                              False                        False
# 3                              False                        False
# 4                              False                        False
# 5                              False                        False
# 6                              False                        False
#
#          ILLNESS_BEDGRADE_Moderate-3  ILLNESS_BEDGRADE_Moderate-4  \
# CASE_ID
# 1                              False                        False
# 3                              False                        False
# 4                              False                        False
# 5                              False                        False
# 6                              False                        False
#
#          DEPARTMENT_ILLNESS_TB & Chest disease-Minor  \
# CASE_ID
# 1                                              False
# 3                                              False
# 4                                              False
# 5                                              False
# 6                                              False
#
#          DEPARTMENT_ILLNESS_TB & Chest disease-Moderate  \
# CASE_ID
# 1                                                 False
# 3                                                 False
# 4                                                 False
# 5                                                 False
# 6                                                 False
#
#          DEPARTMENT_ILLNESS_anesthesia-Extreme  \
# CASE_ID
# 1                                        False
# 3                                         True
# 4                                        False
# 5                                        False
# 6                                         True
#
#          DEPARTMENT_ILLNESS_anesthesia-Minor  \
# CASE_ID
# 1                                      False
# 3                                      False
# 4                                      False
# 5                                      False
# 6                                      False
#
#          DEPARTMENT_ILLNESS_anesthesia-Moderate  \
# CASE_ID
# 1                                         False
# 3                                         False
# 4                                         False
# 5                                         False
# 6                                         False
#
#          DEPARTMENT_ILLNESS_gynecology-Extreme  \
# CASE_ID
# 1                                        False
# 3                                        False
# 4                                        False
# 5                                        False
# 6                                        False
#
#          DEPARTMENT_ILLNESS_gynecology-Minor  \
# CASE_ID
# 1                                      False
# 3                                      False
# 4                                      False
# 5                                      False
# 6                                      False
#
#          DEPARTMENT_ILLNESS_gynecology-Moderate  \
# CASE_ID
# 1                                         False
# 3                                         False
# 4                                         False
# 5                                         False
# 6                                         False
#
#          DEPARTMENT_ILLNESS_radiotherapy-Extreme  \
# CASE_ID
# 1                                           True
# 3                                          False
# 4                                           True
# 5                                           True
# 6                                          False
#
#          DEPARTMENT_ILLNESS_radiotherapy-Minor  \
# CASE_ID
# 1                                        False
# 3                                        False
# 4                                        False
# 5                                        False
# 6                                        False
#
#          DEPARTMENT_ILLNESS_radiotherapy-Moderate  \
# CASE_ID
# 1                                           False
# 3                                           False
# 4                                           False
# 5                                           False
# 6                                           False
#
#          DEPARTMENT_ILLNESS_surgery-Extreme  DEPARTMENT_ILLNESS_surgery-Minor  \
# CASE_ID
# 1                                     False                             False
# 3                                     False                             False
# 4                                     False                             False
# 5                                     False                             False
# 6                                     False                             False
#
#          DEPARTMENT_ILLNESS_surgery-Moderate
# CASE_ID
# 1                                      False
# 3                                      False
# 4                                      False
# 5                                      False
# 6                                      False

# %%
# %%writefile LOS_Preprocessing.py

import pandas as pd
import numpy as np

## Preprocessing Function
def preprocess_data(df):
    # Columns to drop
    cols_to_drop = ['HOSPITAL_CODE','PATIENTID','ADMISSION_DATE','DISCHARGE_DATE']
    df = df.drop(cols_to_drop,axis=1)
    
    # Setting the index
    df.set_index('CASE_ID',inplace=True)

    # Fixing the data types issue
    num_columns = ['AVAILABLE_EXTRA_ROOMS_IN_HOSPITAL','VISITORS_WITH_PATIENT','ADMISSION_DEPOSIT','LOS']
    cat_columns = [col for col in df.columns.tolist() if col not in num_columns]
    
    for col in cat_columns:
        df[col] = df[col].astype(object)    
    
    for col in num_columns:
        df[col] = df[col].astype(int)
    
    # One-Hot Encoding
    df_final = pd.get_dummies(df)    
    
    return df_final
# Out:
# Overwriting LOS_Preprocessing.py

# %% [markdown]
# ## Feature Selection:

# %%
df_final = data_after_process.copy()
print(df_final.shape)
# Out:
# (236704, 134)

# %%
# Creating Train and test split
from sklearn.model_selection import train_test_split

X = df_final.drop('LOS',axis=1)
Y = df_final[['LOS']]

x_train, x_test, y_train, y_test = train_test_split(X,Y,test_size=0.3,stratify=Y)
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (165692, 133) (165692, 1)
# (71012, 133) (71012, 1)

# %% [markdown]
# #### 1. Dtree Selection:

# %%
from sklearn.tree import DecisionTreeRegressor

dtree = DecisionTreeRegressor()
dtree.fit(x_train,y_train)
dtree.score(x_train,y_train)
# Out:
# 0.9999978634697589

# %%
# Feature Importance
feat_imp = (pd.DataFrame(zip(x_train.columns,dtree.feature_importances_),columns=['feature','importance'])
            .sort_values(by='importance',ascending=False))
display(feat_imp[:20])

plt.figure(figsize=(9,7))
sns.barplot(y='feature',x='importance',data=feat_imp[:20],orient='h')
plt.show()
# Out:
#                               feature  importance
# 1               VISITORS_WITH_PATIENT    0.189996
# 2                   ADMISSION_DEPOSIT    0.170179
# 25                        WARD_TYPE_Q    0.069064
# 0   AVAILABLE_EXTRA_ROOMS_IN_HOSPITAL    0.043924
# 88                ADMISSION_MONTH_Nov    0.033168
# 27                        WARD_TYPE_S    0.017524
# 90                ADMISSION_MONTH_Sep    0.013617
# 89                ADMISSION_MONTH_Oct    0.012698
# 82                          AGE_41-50    0.012181
# 93                  ADMISSION_DAY_Sun    0.011838
# 81                          AGE_31-40    0.011810
# 96                  ADMISSION_DAY_Wed    0.011661
# 94                  ADMISSION_DAY_Thu    0.011639
# 95                  ADMISSION_DAY_Tue    0.011564
# 83                          AGE_51-60    0.011452
# 91                  ADMISSION_DAY_Mon    0.011066
# 92                  ADMISSION_DAY_Sat    0.010641
# 85                          AGE_71-80    0.010413
# 75           TYPE_OF_ADMISSION_Trauma    0.010064
# 46                CITY_CODE_PATIENT_8    0.010022

# %%
# Selecting features with atleast 1% importance value
display(feat_imp[feat_imp['importance']>=0.01])
final_features_dtree = feat_imp[feat_imp['importance']>=0.01]['feature'].values.tolist()
print(len(final_features_dtree))
final_features_dtree[:5]
# Out:
#                               feature  importance
# 1               VISITORS_WITH_PATIENT    0.195471
# 2                   ADMISSION_DEPOSIT    0.170136
# 25                        WARD_TYPE_Q    0.069969
# 0   AVAILABLE_EXTRA_ROOMS_IN_HOSPITAL    0.045313
# 88                ADMISSION_MONTH_Nov    0.034071
# 27                        WARD_TYPE_S    0.013793
# 89                ADMISSION_MONTH_Oct    0.012854
# 90                ADMISSION_MONTH_Sep    0.012651
# 82                          AGE_41-50    0.011920
# 92                  ADMISSION_DAY_Sat    0.011864
# 94                  ADMISSION_DAY_Thu    0.011526
# 81                          AGE_31-40    0.011503
# 95                  ADMISSION_DAY_Tue    0.011472
# 96                  ADMISSION_DAY_Wed    0.011460
# 83                          AGE_51-60    0.011218
# 93                  ADMISSION_DAY_Sun    0.011119
# 91                  ADMISSION_DAY_Mon    0.010988
# 85                          AGE_71-80    0.010611
# 75           TYPE_OF_ADMISSION_Trauma    0.010207
# 19
# ['VISITORS_WITH_PATIENT',
#  'ADMISSION_DEPOSIT',
#  'WARD_TYPE_Q',
#  'AVAILABLE_EXTRA_ROOMS_IN_HOSPITAL',
#  'ADMISSION_MONTH_Nov']

# %% [markdown]
# #### 2. XGB Selection:

# %%
import xgboost as xgb

xgb_ = xgb.XGBRegressor()
xgb_.fit(x_train,y_train)
xgb_.score(x_train,y_train)
# Out:
# 0.421082079410553

# %%
# Feature Importance
feat_imp = (pd.DataFrame(zip(x_train.columns,xgb_.feature_importances_),columns=['feature','importance'])
            .sort_values(by='importance',ascending=False))
display(feat_imp[:20])

plt.figure(figsize=(9,7))
sns.barplot(y='feature',x='importance',data=feat_imp[:20],orient='h')
plt.show()
# Out:
#                               feature  importance
# 25                          AGE_31-40    0.237141
# 1                   ADMISSION_DAY_Tue    0.059019
# 14                  ADMISSION_DEPOSIT    0.028101
# 9                   ADMISSION_DAY_Wed    0.010875
# 0                 ADMISSION_MONTH_Nov    0.008883
# 18              VISITORS_WITH_PATIENT    0.007427
# 17                  ADMISSION_DAY_Mon    0.006520
# 22  AVAILABLE_EXTRA_ROOMS_IN_HOSPITAL    0.006506
# 3                         WARD_TYPE_R    0.005705
# 13               CITY_CODE_HOSPITAL_2    0.005557
# 8                         WARD_TYPE_S    0.004852
# 15           TYPE_OF_ADMISSION_Trauma    0.004587
# 19                  ADMISSION_DAY_Sun    0.004459
# 4                CITY_CODE_HOSPITAL_7    0.004451
# 24                          AGE_71-80    0.004416
# 20                CITY_CODE_PATIENT_8    0.004297
# 6                   ADMISSION_DAY_Sat    0.004056
# 11                        BED_GRADE_2    0.003923
# 21                  ADMISSION_DAY_Thu    0.003921
# 12         ILLNESS_BEDGRADE_Extreme-1    0.003842

# %%
# Selecting features with atleast 1% importance value
display(feat_imp[feat_imp['importance']>=0.01][:10])
final_features_xgb = feat_imp[feat_imp['importance']>=0.01]['feature'].values.tolist()
print(len(final_features_xgb))
final_features_xgb[:5]
# Out:
#                         feature  importance
# 25                  WARD_TYPE_Q    0.237141
# 88          ADMISSION_MONTH_Nov    0.076534
# 1         VISITORS_WITH_PATIENT    0.059019
# 75     TYPE_OF_ADMISSION_Trauma    0.035102
# 77    SEVERITY_OF_ILLNESS_Minor    0.028289
# 14         CITY_CODE_HOSPITAL_7    0.028101
# 27                  WARD_TYPE_S    0.023780
# 89          ADMISSION_MONTH_Oct    0.022654
# 36                  BED_GRADE_2    0.020519
# 105  ILLNESS_BEDGRADE_Extreme-1    0.019946
# 13
# ['WARD_TYPE_Q',
#  'ADMISSION_MONTH_Nov',
#  'VISITORS_WITH_PATIENT',
#  'TYPE_OF_ADMISSION_Trauma',
#  'SEVERITY_OF_ILLNESS_Minor']

# %% [markdown]
# #### Feature Union:

# %%
print("Total Features from Dtree: "+str(len(final_features_dtree)))
print("Total Features from XGB: "+str(len(final_features_xgb)))
# Out:
# Total Features from Dtree: 19
# Total Features from XGB: 13

# %%
model_features =  list(set(final_features_dtree).union(set(final_features_xgb)))
print("Final Features from both Dtree & XGB: "+str(len(model_features)))
# Out:
# Final Features from both Dtree & XGB: 26

# %%
model_features
# Out:
# ['ADMISSION_MONTH_Nov',
#  'ADMISSION_DAY_Tue',
#  'ADMISSION_MONTH_Oct',
#  'WARD_TYPE_R',
#  'CITY_CODE_HOSPITAL_7',
#  'WARD_TYPE_Q',
#  'ADMISSION_DAY_Sat',
#  'AGE_41-50',
#  'WARD_TYPE_S',
#  'ADMISSION_DAY_Wed',
#  'ADMISSION_MONTH_Sep',
#  'BED_GRADE_2',
#  'ILLNESS_BEDGRADE_Extreme-1',
#  'CITY_CODE_HOSPITAL_2',
#  'ADMISSION_DEPOSIT',
#  'TYPE_OF_ADMISSION_Trauma',
#  'AGE_51-60',
#  'ADMISSION_DAY_Mon',
#  'VISITORS_WITH_PATIENT',
#  'ADMISSION_DAY_Sun',
#  'CITY_CODE_PATIENT_8',
#  'ADMISSION_DAY_Thu',
#  'AVAILABLE_EXTRA_ROOMS_IN_HOSPITAL',
#  'SEVERITY_OF_ILLNESS_Minor',
#  'AGE_71-80',
#  'AGE_31-40']

# %%
df_final[model_features+['LOS']].to_pickle('MODEL_training_data_with_final_features.pkl')

# %%
import pickle

final_feats_list = model_features+['LOS']

with open('MODEL_FEATS.pkl','wb') as F:
    pickle.dump(final_feats_list,F)

# %%
df_final
# Out:
#          AVAILABLE_EXTRA_ROOMS_IN_HOSPITAL  VISITORS_WITH_PATIENT  \
# CASE_ID
# 1                                        3                      2
# 3                                        2                      2
# 4                                        2                      2
# 5                                        2                      2
# 6                                        2                      2
# ...                                    ...                    ...
# 255877                                   3                      4
# 255879                                   3                     15
# 255880                                   3                     15
# 255882                                   4                      4
# 255883                                   4                      4
#
#          ADMISSION_DEPOSIT  LOS  HOSPITAL_TYPE_CODE_b  HOSPITAL_TYPE_CODE_c  \
# CASE_ID
# 1                     4911   10                 False                  True
# 3                     4745   40                 False                 False
# 4                     7272   50                  True                 False
# 5                     5558   50                  True                 False
# 6                     4449   20                 False                 False
# ...                    ...  ...                   ...                   ...
# 255877                4116   30                 False                 False
# 255879                4587   50                 False                  True
# 255880                4241   50                 False                  True
# 255882                3036   20                 False                 False
# 255883                4326   30                 False                 False
#
#          HOSPITAL_TYPE_CODE_d  HOSPITAL_TYPE_CODE_e  HOSPITAL_TYPE_CODE_f  \
# CASE_ID
# 1                       False                 False                 False
# 3                       False                  True                 False
# 4                       False                 False                 False
# 5                       False                 False                 False
# 6                       False                 False                 False
# ...                       ...                   ...                   ...
# 255877                  False                 False                 False
# 255879                  False                 False                 False
# 255880                  False                 False                 False
# 255882                  False                 False                 False
# 255883                  False                 False                 False
#
#          HOSPITAL_TYPE_CODE_g  CITY_CODE_HOSPITAL_2  CITY_CODE_HOSPITAL_3  \
# CASE_ID
# 1                       False                 False                  True
# 3                       False                 False                 False
# 4                       False                  True                 False
# 5                       False                  True                 False
# 6                       False                 False                 False
# ...                       ...                   ...                   ...
# 255877                  False                 False                 False
# 255879                  False                 False                  True
# 255880                  False                 False                  True
# 255882                  False                 False                 False
# 255883                  False                 False                 False
#
#          CITY_CODE_HOSPITAL_4  CITY_CODE_HOSPITAL_5  CITY_CODE_HOSPITAL_6  \
# CASE_ID
# 1                       False                 False                 False
# 3                       False                 False                 False
# 4                       False                 False                 False
# 5                       False                 False                 False
# 6                       False                 False                  True
# ...                       ...                   ...                   ...
# 255877                  False                 False                  True
# 255879                  False                 False                 False
# 255880                  False                 False                 False
# 255882                  False                 False                 False
# 255883                  False                 False                 False
#
#          CITY_CODE_HOSPITAL_7  CITY_CODE_HOSPITAL_9  CITY_CODE_HOSPITAL_10  \
# CASE_ID
# 1                       False                 False                  False
# 3                       False                 False                  False
# 4                       False                 False                  False
# 5                       False                 False                  False
# 6                       False                 False                  False
# ...                       ...                   ...                    ...
# 255877                  False                 False                  False
# 255879                  False                 False                  False
# 255880                  False                 False                  False
# 255882                   True                 False                  False
# 255883                  False                 False                  False
#
#          CITY_CODE_HOSPITAL_11  CITY_CODE_HOSPITAL_13  HOSPITAL_REGION_CODE_Y  \
# CASE_ID
# 1                        False                  False                   False
# 3                        False                  False                   False
# 4                        False                  False                    True
# 5                        False                  False                    True
# 6                        False                  False                   False
# ...                        ...                    ...                     ...
# 255877                   False                  False                   False
# 255879                   False                  False                   False
# 255880                   False                  False                   False
# 255882                   False                  False                    True
# 255883                   False                  False                   False
#
#          HOSPITAL_REGION_CODE_Z  DEPARTMENT_anesthesia  DEPARTMENT_gynecology  \
# CASE_ID
# 1                          True                  False                  False
# 3                         False                   True                  False
# 4                         False                  False                  False
# 5                         False                  False                  False
# 6                         False                   True                  False
# ...                         ...                    ...                    ...
# 255877                    False                  False                   True
# 255879                     True                  False                   True
# 255880                     True                  False                   True
# 255882                    False                  False                   True
# 255883                    False                  False                   True
#
#          DEPARTMENT_radiotherapy  DEPARTMENT_surgery  WARD_TYPE_Q  \
# CASE_ID
# 1                           True               False        False
# 3                          False               False        False
# 4                           True               False        False
# 5                           True               False        False
# 6                          False               False        False
# ...                          ...                 ...          ...
# 255877                     False               False         True
# 255879                     False               False        False
# 255880                     False               False        False
# 255882                     False               False         True
# 255883                     False               False         True
#
#          WARD_TYPE_R  WARD_TYPE_S  WARD_TYPE_T  WARD_TYPE_U  \
# CASE_ID
# 1               True        False        False        False
# 3              False         True        False        False
# 4               True        False        False        False
# 5              False         True        False        False
# 6              False         True        False        False
# ...              ...          ...          ...          ...
# 255877         False        False        False        False
# 255879          True        False        False        False
# 255880          True        False        False        False
# 255882         False        False        False        False
# 255883         False        False        False        False
#
#          WARD_FACILITY_CODE_B  WARD_FACILITY_CODE_C  WARD_FACILITY_CODE_D  \
# CASE_ID
# 1                       False                 False                 False
# 3                       False                 False                 False
# 4                       False                 False                  True
# 5                       False                 False                  True
# 6                       False                 False                 False
# ...                       ...                   ...                   ...
# 255877                  False                 False                 False
# 255879                  False                 False                 False
# 255880                  False                 False                 False
# 255882                  False                  True                 False
# 255883                  False                 False                 False
#
#          WARD_FACILITY_CODE_E  WARD_FACILITY_CODE_F  BED_GRADE_1  BED_GRADE_2  \
# CASE_ID
# 1                       False                  True        False         True
# 3                        True                 False        False         True
# 4                       False                 False        False         True
# 5                       False                 False        False         True
# 6                       False                  True        False         True
# ...                       ...                   ...          ...          ...
# 255877                  False                  True        False         True
# 255879                  False                 False        False        False
# 255880                  False                 False        False        False
# 255882                  False                 False         True        False
# 255883                   True                 False        False         True
#
#          BED_GRADE_3  BED_GRADE_4  CITY_CODE_PATIENT_1  CITY_CODE_PATIENT_2  \
# CASE_ID
# 1              False        False                False                False
# 3              False        False                False                False
# 4              False        False                False                False
# 5              False        False                False                False
# 6              False        False                False                False
# ...              ...          ...                  ...                  ...
# 255877         False        False                False                False
# 255879         False         True                False                False
# 255880         False         True                False                False
# 255882         False        False                False                False
# 255883         False        False                False                False
#
#          CITY_CODE_PATIENT_3  CITY_CODE_PATIENT_4  CITY_CODE_PATIENT_5  \
# CASE_ID
# 1                      False                False                False
# 3                      False                False                False
# 4                      False                False                False
# 5                      False                False                False
# 6                      False                False                False
# ...                      ...                  ...                  ...
# 255877                 False                False                False
# 255879                 False                False                False
# 255880                 False                False                False
# 255882                 False                False                False
# 255883                 False                 True                False
#
#          CITY_CODE_PATIENT_6  CITY_CODE_PATIENT_7  CITY_CODE_PATIENT_8  \
# CASE_ID
# 1                      False                 True                False
# 3                      False                 True                False
# 4                      False                 True                False
# 5                      False                 True                False
# 6                      False                 True                False
# ...                      ...                  ...                  ...
# 255877                 False                False                 True
# 255879                 False                False                False
# 255880                 False                False                False
# 255882                 False                False                 True
# 255883                 False                False                False
#
#          CITY_CODE_PATIENT_9  CITY_CODE_PATIENT_10  CITY_CODE_PATIENT_11  \
# CASE_ID
# 1                      False                 False                 False
# 3                      False                 False                 False
# 4                      False                 False                 False
# 5                      False                 False                 False
# 6                      False                 False                 False
# ...                      ...                   ...                   ...
# 255877                 False                 False                 False
# 255879                 False                 False                 False
# 255880                 False                 False                 False
# 255882                 False                 False                 False
# 255883                 False                 False                 False
#
#          CITY_CODE_PATIENT_12  CITY_CODE_PATIENT_13  CITY_CODE_PATIENT_14  \
# CASE_ID
# 1                       False                 False                 False
# 3                       False                 False                 False
# 4                       False                 False                 False
# 5                       False                 False                 False
# 6                       False                 False                 False
# ...                       ...                   ...                   ...
# 255877                  False                 False                 False
# 255879                  False                 False                 False
# 255880                  False                 False                 False
# 255882                  False                 False                 False
# 255883                  False                 False                 False
#
#          CITY_CODE_PATIENT_15  CITY_CODE_PATIENT_16  CITY_CODE_PATIENT_18  \
# CASE_ID
# 1                       False                 False                 False
# 3                       False                 False                 False
# 4                       False                 False                 False
# 5                       False                 False                 False
# 6                       False                 False                 False
# ...                       ...                   ...                   ...
# 255877                  False                 False                 False
# 255879                  False                 False                 False
# 255880                  False                 False                 False
# 255882                  False                 False                 False
# 255883                  False                 False                 False
#
#          CITY_CODE_PATIENT_19  CITY_CODE_PATIENT_20  CITY_CODE_PATIENT_21  \
# CASE_ID
# 1                       False                 False                 False
# 3                       False                 False                 False
# 4                       False                 False                 False
# 5                       False                 False                 False
# 6                       False                 False                 False
# ...                       ...                   ...                   ...
# 255877                  False                 False                 False
# 255879                  False                 False                 False
# 255880                  False                 False                 False
# 255882                  False                 False                 False
# 255883                  False                 False                 False
#
#          CITY_CODE_PATIENT_22  CITY_CODE_PATIENT_23  CITY_CODE_PATIENT_24  \
# CASE_ID
# 1                       False                 False                 False
# 3                       False                 False                 False
# 4                       False                 False                 False
# 5                       False                 False                 False
# 6                       False                 False                 False
# ...                       ...                   ...                   ...
# 255877                  False                 False                 False
# 255879                  False                 False                 False
# 255880                  False                 False                 False
# 255882                  False                 False                 False
# 255883                  False                 False                 False
#
#          CITY_CODE_PATIENT_25  CITY_CODE_PATIENT_26  CITY_CODE_PATIENT_27  \
# CASE_ID
# 1                       False                 False                 False
# 3                       False                 False                 False
# 4                       False                 False                 False
# 5                       False                 False                 False
# 6                       False                 False                 False
# ...                       ...                   ...                   ...
# 255877                  False                 False                 False
# 255879                  False                 False                 False
# 255880                  False                 False                 False
# 255882                  False                 False                 False
# 255883                  False                 False                 False
#
#          CITY_CODE_PATIENT_28  CITY_CODE_PATIENT_29  CITY_CODE_PATIENT_30  \
# CASE_ID
# 1                       False                 False                 False
# 3                       False                 False                 False
# 4                       False                 False                 False
# 5                       False                 False                 False
# 6                       False                 False                 False
# ...                       ...                   ...                   ...
# 255877                  False                 False                 False
# 255879                  False                 False                 False
# 255880                  False                 False                 False
# 255882                  False                 False                 False
# 255883                  False                 False                 False
#
#          CITY_CODE_PATIENT_31  CITY_CODE_PATIENT_32  CITY_CODE_PATIENT_33  \
# CASE_ID
# 1                       False                 False                 False
# 3                       False                 False                 False
# 4                       False                 False                 False
# 5                       False                 False                 False
# 6                       False                 False                 False
# ...                       ...                   ...                   ...
# 255877                  False                 False                 False
# 255879                  False                 False                 False
# 255880                  False                 False                 False
# 255882                  False                 False                 False
# 255883                  False                 False                 False
#
#          CITY_CODE_PATIENT_34  CITY_CODE_PATIENT_35  CITY_CODE_PATIENT_36  \
# CASE_ID
# 1                       False                 False                 False
# 3                       False                 False                 False
# 4                       False                 False                 False
# 5                       False                 False                 False
# 6                       False                 False                 False
# ...                       ...                   ...                   ...
# 255877                  False                 False                 False
# 255879                  False                 False                 False
# 255880                  False                 False                 False
# 255882                  False                 False                 False
# 255883                  False                 False                 False
#
#          CITY_CODE_PATIENT_37  TYPE_OF_ADMISSION_Trauma  \
# CASE_ID
# 1                       False                     False
# 3                       False                      True
# 4                       False                      True
# 5                       False                      True
# 6                       False                      True
# ...                       ...                       ...
# 255877                  False                      True
# 255879                  False                     False
# 255880                  False                     False
# 255882                  False                     False
# 255883                  False                      True
#
#          TYPE_OF_ADMISSION_Urgent  SEVERITY_OF_ILLNESS_Minor  \
# CASE_ID
# 1                           False                      False
# 3                           False                      False
# 4                           False                      False
# 5                           False                      False
# 6                           False                      False
# ...                           ...                        ...
# 255877                      False                      False
# 255879                      False                      False
# 255880                      False                      False
# 255882                      False                      False
# 255883                      False                      False
#
#          SEVERITY_OF_ILLNESS_Moderate  AGE_20-Nov  AGE_21-30  AGE_31-40  \
# CASE_ID
# 1                               False       False      False      False
# 3                               False       False      False      False
# 4                               False       False      False      False
# 5                               False       False      False      False
# 6                               False       False      False      False
# ...                               ...         ...        ...        ...
# 255877                           True       False      False      False
# 255879                           True       False      False      False
# 255880                           True       False      False      False
# 255882                          False       False      False      False
# 255883                          False       False      False       True
#
#          AGE_41-50  AGE_51-60  AGE_61-70  AGE_71-80  AGE_81-90  AGE_91-100  \
# CASE_ID
# 1            False       True      False      False      False       False
# 3            False       True      False      False      False       False
# 4            False       True      False      False      False       False
# 5            False       True      False      False      False       False
# 6            False       True      False      False      False       False
# ...            ...        ...        ...        ...        ...         ...
# 255877       False      False      False      False      False       False
# 255879        True      False      False      False      False       False
# 255880        True      False      False      False      False       False
# 255882        True      False      False      False      False       False
# 255883       False      False      False      False      False       False
#
#          ADMISSION_MONTH_Nov  ADMISSION_MONTH_Oct  ADMISSION_MONTH_Sep  \
# CASE_ID
# 1                      False                False                False
# 3                      False                False                 True
# 4                      False                False                 True
# 5                       True                False                False
# 6                      False                False                 True
# ...                      ...                  ...                  ...
# 255877                 False                False                False
# 255879                 False                False                 True
# 255880                  True                False                False
# 255882                 False                False                False
# 255883                 False                 True                False
#
#          ADMISSION_DAY_Mon  ADMISSION_DAY_Sat  ADMISSION_DAY_Sun  \
# CASE_ID
# 1                    False              False              False
# 3                    False              False              False
# 4                    False              False              False
# 5                    False              False              False
# 6                    False              False              False
# ...                    ...                ...                ...
# 255877               False               True              False
# 255879               False              False              False
# 255880               False               True              False
# 255882               False              False              False
# 255883               False              False               True
#
#          ADMISSION_DAY_Thu  ADMISSION_DAY_Tue  ADMISSION_DAY_Wed  \
# CASE_ID
# 1                    False              False               True
# 3                    False              False              False
# 4                     True              False              False
# 5                    False              False               True
# 6                    False              False              False
# ...                    ...                ...                ...
# 255877               False              False              False
# 255879               False              False              False
# 255880               False              False              False
# 255882               False               True              False
# 255883               False              False              False
#
#          ADMISSION_ILLNESS_Emergency-Minor  \
# CASE_ID
# 1                                    False
# 3                                    False
# 4                                    False
# 5                                    False
# 6                                    False
# ...                                    ...
# 255877                               False
# 255879                               False
# 255880                               False
# 255882                               False
# 255883                               False
#
#          ADMISSION_ILLNESS_Emergency-Moderate  \
# CASE_ID
# 1                                       False
# 3                                       False
# 4                                       False
# 5                                       False
# 6                                       False
# ...                                       ...
# 255877                                  False
# 255879                                   True
# 255880                                   True
# 255882                                  False
# 255883                                  False
#
#          ADMISSION_ILLNESS_Trauma-Extreme  ADMISSION_ILLNESS_Trauma-Minor  \
# CASE_ID
# 1                                   False                           False
# 3                                    True                           False
# 4                                    True                           False
# 5                                    True                           False
# 6                                    True                           False
# ...                                   ...                             ...
# 255877                              False                           False
# 255879                              False                           False
# 255880                              False                           False
# 255882                              False                           False
# 255883                               True                           False
#
#          ADMISSION_ILLNESS_Trauma-Moderate  ADMISSION_ILLNESS_Urgent-Extreme  \
# CASE_ID
# 1                                    False                             False
# 3                                    False                             False
# 4                                    False                             False
# 5                                    False                             False
# 6                                    False                             False
# ...                                    ...                               ...
# 255877                                True                             False
# 255879                               False                             False
# 255880                               False                             False
# 255882                               False                             False
# 255883                               False                             False
#
#          ADMISSION_ILLNESS_Urgent-Minor  ADMISSION_ILLNESS_Urgent-Moderate  \
# CASE_ID
# 1                                 False                              False
# 3                                 False                              False
# 4                                 False                              False
# 5                                 False                              False
# 6                                 False                              False
# ...                                 ...                                ...
# 255877                            False                              False
# 255879                            False                              False
# 255880                            False                              False
# 255882                            False                              False
# 255883                            False                              False
#
#          ILLNESS_BEDGRADE_Extreme-1  ILLNESS_BEDGRADE_Extreme-2  \
# CASE_ID
# 1                             False                        True
# 3                             False                        True
# 4                             False                        True
# 5                             False                        True
# 6                             False                        True
# ...                             ...                         ...
# 255877                        False                       False
# 255879                        False                       False
# 255880                        False                       False
# 255882                         True                       False
# 255883                        False                        True
#
#          ILLNESS_BEDGRADE_Extreme-3  ILLNESS_BEDGRADE_Extreme-4  \
# CASE_ID
# 1                             False                       False
# 3                             False                       False
# 4                             False                       False
# 5                             False                       False
# 6                             False                       False
# ...                             ...                         ...
# 255877                        False                       False
# 255879                        False                       False
# 255880                        False                       False
# 255882                        False                       False
# 255883                        False                       False
#
#          ILLNESS_BEDGRADE_Minor-0  ILLNESS_BEDGRADE_Minor-1  \
# CASE_ID
# 1                           False                     False
# 3                           False                     False
# 4                           False                     False
# 5                           False                     False
# 6                           False                     False
# ...                           ...                       ...
# 255877                      False                     False
# 255879                      False                     False
# 255880                      False                     False
# 255882                      False                     False
# 255883                      False                     False
#
#          ILLNESS_BEDGRADE_Minor-2  ILLNESS_BEDGRADE_Minor-3  \
# CASE_ID
# 1                           False                     False
# 3                           False                     False
# 4                           False                     False
# 5                           False                     False
# 6                           False                     False
# ...                           ...                       ...
# 255877                      False                     False
# 255879                      False                     False
# 255880                      False                     False
# 255882                      False                     False
# 255883                      False                     False
#
#          ILLNESS_BEDGRADE_Minor-4  ILLNESS_BEDGRADE_Moderate-0  \
# CASE_ID
# 1                           False                        False
# 3                           False                        False
# 4                           False                        False
# 5                           False                        False
# 6                           False                        False
# ...                           ...                          ...
# 255877                      False                        False
# 255879                      False                        False
# 255880                      False                        False
# 255882                      False                        False
# 255883                      False                        False
#
#          ILLNESS_BEDGRADE_Moderate-1  ILLNESS_BEDGRADE_Moderate-2  \
# CASE_ID
# 1                              False                        False
# 3                              False                        False
# 4                              False                        False
# 5                              False                        False
# 6                              False                        False
# ...                              ...                          ...
# 255877                         False                         True
# 255879                         False                        False
# 255880                         False                        False
# 255882                         False                        False
# 255883                         False                        False
#
#          ILLNESS_BEDGRADE_Moderate-3  ILLNESS_BEDGRADE_Moderate-4  \
# CASE_ID
# 1                              False                        False
# 3                              False                        False
# 4                              False                        False
# 5                              False                        False
# 6                              False                        False
# ...                              ...                          ...
# 255877                         False                        False
# 255879                         False                         True
# 255880                         False                         True
# 255882                         False                        False
# 255883                         False                        False
#
#          DEPARTMENT_ILLNESS_TB & Chest disease-Minor  \
# CASE_ID
# 1                                              False
# 3                                              False
# 4                                              False
# 5                                              False
# 6                                              False
# ...                                              ...
# 255877                                         False
# 255879                                         False
# 255880                                         False
# 255882                                         False
# 255883                                         False
#
#          DEPARTMENT_ILLNESS_TB & Chest disease-Moderate  \
# CASE_ID
# 1                                                 False
# 3                                                 False
# 4                                                 False
# 5                                                 False
# 6                                                 False
# ...                                                 ...
# 255877                                            False
# 255879                                            False
# 255880                                            False
# 255882                                            False
# 255883                                            False
#
#          DEPARTMENT_ILLNESS_anesthesia-Extreme  \
# CASE_ID
# 1                                        False
# 3                                         True
# 4                                        False
# 5                                        False
# 6                                         True
# ...                                        ...
# 255877                                   False
# 255879                                   False
# 255880                                   False
# 255882                                   False
# 255883                                   False
#
#          DEPARTMENT_ILLNESS_anesthesia-Minor  \
# CASE_ID
# 1                                      False
# 3                                      False
# 4                                      False
# 5                                      False
# 6                                      False
# ...                                      ...
# 255877                                 False
# 255879                                 False
# 255880                                 False
# 255882                                 False
# 255883                                 False
#
#          DEPARTMENT_ILLNESS_anesthesia-Moderate  \
# CASE_ID
# 1                                         False
# 3                                         False
# 4                                         False
# 5                                         False
# 6                                         False
# ...                                         ...
# 255877                                    False
# 255879                                    False
# 255880                                    False
# 255882                                    False
# 255883                                    False
#
#          DEPARTMENT_ILLNESS_gynecology-Extreme  \
# CASE_ID
# 1                                        False
# 3                                        False
# 4                                        False
# 5                                        False
# 6                                        False
# ...                                        ...
# 255877                                   False
# 255879                                   False
# 255880                                   False
# 255882                                    True
# 255883                                    True
#
#          DEPARTMENT_ILLNESS_gynecology-Minor  \
# CASE_ID
# 1                                      False
# 3                                      False
# 4                                      False
# 5                                      False
# 6                                      False
# ...                                      ...
# 255877                                 False
# 255879                                 False
# 255880                                 False
# 255882                                 False
# 255883                                 False
#
#          DEPARTMENT_ILLNESS_gynecology-Moderate  \
# CASE_ID
# 1                                         False
# 3                                         False
# 4                                         False
# 5                                         False
# 6                                         False
# ...                                         ...
# 255877                                     True
# 255879                                     True
# 255880                                     True
# 255882                                    False
# 255883                                    False
#
#          DEPARTMENT_ILLNESS_radiotherapy-Extreme  \
# CASE_ID
# 1                                           True
# 3                                          False
# 4                                           True
# 5                                           True
# 6                                          False
# ...                                          ...
# 255877                                     False
# 255879                                     False
# 255880                                     False
# 255882                                     False
# 255883                                     False
#
#          DEPARTMENT_ILLNESS_radiotherapy-Minor  \
# CASE_ID
# 1                                        False
# 3                                        False
# 4                                        False
# 5                                        False
# 6                                        False
# ...                                        ...
# 255877                                   False
# 255879                                   False
# 255880                                   False
# 255882                                   False
# 255883                                   False
#
#          DEPARTMENT_ILLNESS_radiotherapy-Moderate  \
# CASE_ID
# 1                                           False
# 3                                           False
# 4                                           False
# 5                                           False
# 6                                           False
# ...                                           ...
# 255877                                      False
# 255879                                      False
# 255880                                      False
# 255882                                      False
# 255883                                      False
#
#          DEPARTMENT_ILLNESS_surgery-Extreme  DEPARTMENT_ILLNESS_surgery-Minor  \
# CASE_ID
# 1                                     False                             False
# 3                                     False                             False
# 4                                     False                             False
# 5                                     False                             False
# 6                                     False                             False
# ...                                     ...                               ...
# 255877                                False                             False
# 255879                                False                             False
# 255880                                False                             False
# 255882                                False                             False
# 255883                                False                             False
#
#          DEPARTMENT_ILLNESS_surgery-Moderate
# CASE_ID
# 1                                      False
# 3                                      False
# 4                                      False
# 5                                      False
# 6                                      False
# ...                                      ...
# 255877                                 False
# 255879                                 False
# 255880                                 False
# 255882                                 False
# 255883                                 False
#
# [236704 rows x 134 columns]

# %% [markdown]
# ## Model Building:

# %%
from sklearn.model_selection import train_test_split

df_features = pd.read_pickle('MODEL_training_data_with_final_features.pkl')
print(df_features.shape)
df_features.head(3)
# Out:
# (236704, 27)
#          ADMISSION_MONTH_Nov  ADMISSION_DAY_Tue  ADMISSION_MONTH_Oct  \
# CASE_ID
# 1                      False              False                False
# 3                      False              False                False
# 4                      False              False                False
#
#          WARD_TYPE_R  CITY_CODE_HOSPITAL_7  WARD_TYPE_Q  ADMISSION_DAY_Sat  \
# CASE_ID
# 1               True                 False        False              False
# 3              False                 False        False              False
# 4               True                 False        False              False
#
#          AGE_41-50  WARD_TYPE_S  ADMISSION_DAY_Wed  ADMISSION_MONTH_Sep  \
# CASE_ID
# 1            False        False               True                False
# 3            False         True              False                 True
# 4            False        False              False                 True
#
#          BED_GRADE_2  ILLNESS_BEDGRADE_Extreme-1  CITY_CODE_HOSPITAL_2  \
# CASE_ID
# 1               True                       False                 False
# 3               True                       False                 False
# 4               True                       False                  True
#
#          ADMISSION_DEPOSIT  TYPE_OF_ADMISSION_Trauma  AGE_51-60  \
# CASE_ID
# 1                     4911                     False       True
# 3                     4745                      True       True
# 4                     7272                      True       True
#
#          ADMISSION_DAY_Mon  VISITORS_WITH_PATIENT  ADMISSION_DAY_Sun  \
# CASE_ID
# 1                    False                      2              False
# 3                    False                      2              False
# 4                    False                      2              False
#
#          CITY_CODE_PATIENT_8  ADMISSION_DAY_Thu  \
# CASE_ID
# 1                      False              False
# 3                      False              False
# 4                      False               True
#
#          AVAILABLE_EXTRA_ROOMS_IN_HOSPITAL  SEVERITY_OF_ILLNESS_Minor  \
# CASE_ID
# 1                                        3                      False
# 3                                        2                      False
# 4                                        2                      False
#
#          AGE_71-80  AGE_31-40  LOS
# CASE_ID
# 1            False      False   10
# 3            False      False   40
# 4            False      False   50

# %%
# Train and Test split
X = df_features.drop('LOS',axis=1)
y = df_features[['LOS']]
print(X.shape,y.shape)

x_train, x_test, y_train, y_test = train_test_split(X,y,test_size=0.3,stratify=y,random_state=123)
print(x_train.shape,y_train.shape)
print(x_test.shape,y_test.shape)
# Out:
# (236704, 26) (236704, 1)
# (165692, 26) (165692, 1)
# (71012, 26) (71012, 1)

# %% [markdown]
# ### 1. Linear Regression:

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(x_train, y_train)
lr.score(x_train,y_train)
# Out:
# 0.18143520430239823

# %%
preds = np.ceil(lr.predict(x_test))
rmse = np.sqrt(metrics.mean_squared_error(y_test,preds))
mae = np.sqrt(metrics.mean_absolute_error(y_test,preds))
print("RMSE: ", rmse)
print("MAE: ", mae)
# Out:
# RMSE:  15.22963692330309
# MAE:  3.374968575848166

# %% [markdown]
# ### 2. Random Forest Regression:

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor()
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
# Out:
# 0.8992820049455491

# %%
preds = np.ceil(rf.predict(x_test))
rmse = np.sqrt(metrics.mean_squared_error(y_test,preds))
mae = np.sqrt(metrics.mean_absolute_error(y_test,preds))
print("RMSE: ", rmse)
print("MAE: ", mae)
# Out:
# RMSE:  14.276292891568495
# MAE:  3.2524812984811344

# %%
preds
# Out:
# array([34., 25., 32., ..., 36., 39., 31.])

# %% [markdown]
# ### 3. XGB Regression:

# %%
import xgboost as xgb

xgb_ = xgb.XGBRegressor()
xgb_.fit(x_train,y_train)
xgb_.score(x_train,y_train)
# Out:
# 0.3967684507369995

# %%
preds = np.ceil(xgb_.predict(x_test))
rmse = np.sqrt(metrics.mean_squared_error(y_test,preds))
mae = np.sqrt(metrics.mean_absolute_error(y_test,preds))
print("RMSE: ", rmse)
print("MAE: ", mae)
# Out:
# RMSE:  13.628718175437605
# MAE:  3.171957373736798

# %%
# Saving the trained model
booster = xgb_.get_booster()
booster.save_model('MODEL_XGB.model')
